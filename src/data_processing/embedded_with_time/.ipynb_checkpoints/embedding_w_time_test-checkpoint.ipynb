# %%
import os
import sys
import numpy as np

proj_base_path = '../../../'
sys.path.append(os.path.join(os.getcwd(), proj_base_path))

# %%
import mido
import json
from gensim.models import KeyedVectors
from src.data_processing.embedded_with_time.embed_in_time import mid2np
from src.data_processing.embedded_with_time.unembed_in_time import np2mid

# %%
m = mido.MidiFile('datasets/midi/pokemon/Pokemon_RubySapphireEmerald_-_Slateport_City.mid')
# wv = KeyedVectors.load('datasets/numpy/pokemon_embedded_w_time/just_sparse/meta/_word_vectors_10000_ignore_ratio=0.05.wv', mmap='r')
# with open('datasets/numpy/pokemon_embedded_w_time/just_sparse/meta/_embedding_dict_ignore_ratio=0.05.json') as f:
#     embedding_dict = json.load(f)
    
    
# m = list([n for n in m if n.is_meta or n.channel == 1])#[:26]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-052d16b21c19> in <module>
# ----> 1 m = mido.MidiFile('datasets/midi/pokemon/Pokemon_RubySapphireEmerald_-_Slateport_City.mid')
#       2 wv = KeyedVectors.load('datasets/numpy/pokemon_embedded_w_time/just_sparse/meta/_word_vectors_10000_ignore_ratio=0.05.wv', mmap='r')
#       3 with open('datasets/numpy/pokemon_embedded_w_time/just_sparse/meta/_embedding_dict_ignore_ratio=0.05.json') as f:
#       4     embedding_dict = json.load(f)
#       5
#
# /usr/local/lib/python3.7/site-packages/mido/midifiles/midifiles.py in __init__(self, filename, file, type, ticks_per_beat, charset, debug, clip)
#     313             self._load(file)
#     314         elif self.filename is not None:
# --> 315             with io.open(filename, 'rb') as file:
#     316                 self._load(file)
#     317
#
# ...

# %%
for msg in [m1 for m1 in m]: print(msg)
# Out:
# program_change channel=1 program=10 time=0
# program_change channel=0 program=10 time=0
# note_on channel=0 note=86 velocity=127 time=0
# note_on channel=1 note=74 velocity=96 time=0
# <meta message set_tempo tempo=447761 time=0>
# note_on channel=1 note=74 velocity=0 time=0.22388049999999998
# note_on channel=0 note=86 velocity=0 time=0
# note_on channel=0 note=81 velocity=127 time=0
# note_on channel=1 note=81 velocity=96 time=0
# note_on channel=1 note=81 velocity=0 time=0.22388049999999998
# note_on channel=0 note=81 velocity=0 time=0
# note_on channel=0 note=86 velocity=127 time=0
# note_on channel=1 note=78 velocity=96 time=0
# note_on channel=1 note=78 velocity=0 time=0.22388049999999998
# note_on channel=0 note=86 velocity=0 time=0
# note_on channel=0 note=93 velocity=127 time=0
# note_on channel=1 note=81 velocity=96 time=0
# note_on channel=1 note=81 velocity=0 time=0.22388049999999998
# note_on channel=1 note=74 velocity=96 time=0
# ...

# %%
res = mid2np(m, wv, embedding_dict)
res.shape
# Out:
# [86.0, 127.0, 0.0, 223.8805]
# [74.0, 96.0, 0.0, 223.8805]
# [81.0, 127.0, 223.8805, 223.8805]
# [81.0, 96.0, 0.0, 223.8805]
# [86.0, 127.0, 223.8805, 223.8805]
# [78.0, 96.0, 0.0, 223.8805]
# [93.0, 127.0, 223.8805, 447.761]
# [81.0, 96.0, 0.0, 223.8805]
# [74.0, 96.0, 223.8805, 223.8805]
# [91.0, 127.0, 223.8805, 447.761]
# [81.0, 96.0, 0.0, 223.8805]
# [78.0, 96.0, 223.8805, 223.8805]
# [90.0, 127.0, 223.8805, 223.8805]
# [81.0, 96.0, 0.0, 223.8805]
# [88.0, 127.0, 223.8805, 223.8805]
# [76.0, 96.0, 0.0, 223.8805]
# [85.0, 127.0, 223.8805, 1567.1635]
# [81.0, 96.0, 0.0, 223.8805]
# [79.0, 96.0, 223.8805, 223.8805]
# [81.0, 96.0, 223.8805, 223.8805]
# [76.0, 96.0, 223.8805, 223.8805]
# [81.0, 96.0, 223.8805, 223.8805]
# [79.0, 96.0, 223.8805, 223.8805]
# [81.0, 96.0, 223.8805, 223.8805]
# [85.0, 127.0, 223.8805, 223.8805]
# [76.0, 96.0, 0.0, 223.8805]
# [81.0, 127.0, 223.8805, 223.8805]
# [81.0, 96.0, 0.0, 223.8805]
# [85.0, 127.0, 223.8805, 223.8805]
# [79.0, 96.0, 0.0, 223.8805]
# ...

# %%
asd = np2mid(res, wv)
# Out:
# [86, 127, 0.0, 249.99999236653318]
# [74, 96, 0.0, 249.99999236653318]
# [81, 127, 249.99999236653318, 249.99999236653318]
# [81, 96, 0.0, 249.99999236653318]
# [86, 127, 249.99999236653318, 249.99999236653318]
# [78, 96, 0.0, 249.99999236653318]
# [81, 96, 0.0, 249.99999236653318]
# [74, 96, 249.99999236653318, 249.99999236653318]
# [91, 127, 249.99999236653318, 499.99998473306636]
# [81, 96, 0.0, 249.99999236653318]
# [78, 96, 249.99999236653318, 249.99999236653318]
# [90, 127, 249.99999236653318, 249.99999236653318]
# [81, 96, 0.0, 249.99999236653318]
# [88, 127, 249.99999236653318, 249.99999236653318]
# [76, 96, 0.0, 249.99999236653318]
# [85, 127, 249.99999236653318, 1749.9999465657322]
# [81, 96, 0.0, 249.99999236653318]
# [79, 96, 249.99999236653318, 249.99999236653318]
# [81, 96, 249.99999236653318, 249.99999236653318]
# [76, 96, 249.99999236653318, 249.99999236653318]
# [81, 96, 249.99999236653318, 249.99999236653318]
# [79, 96, 249.99999236653318, 249.99999236653318]
# ...

# %%
# for x in res: print(x[-2:])

# %%
for msg in asd: print(msg)
# Out:
# note_on channel=0 note=74 velocity=96 time=0
# note_on channel=0 note=74 velocity=0 time=0.259375
# note_on channel=0 note=81 velocity=96 time=0
# note_on channel=0 note=81 velocity=0 time=0.259375
# note_on channel=0 note=78 velocity=96 time=0
# note_on channel=0 note=78 velocity=0 time=0.259375
# note_on channel=0 note=81 velocity=96 time=0
# note_on channel=0 note=81 velocity=0 time=0.259375
# note_on channel=0 note=74 velocity=96 time=0
# note_on channel=0 note=74 velocity=0 time=0.259375
# note_on channel=0 note=81 velocity=96 time=0
# note_on channel=0 note=81 velocity=0 time=0.259375
# note_on channel=0 note=78 velocity=96 time=0
# note_on channel=0 note=78 velocity=0 time=0.259375
# note_on channel=0 note=81 velocity=96 time=0
# note_on channel=0 note=81 velocity=0 time=0.259375
# note_on channel=0 note=76 velocity=96 time=0
# note_on channel=0 note=76 velocity=0 time=0.259375
# note_on channel=0 note=81 velocity=96 time=0
# note_on channel=0 note=81 velocity=0 time=0.259375
# ...

# %%
asd.save('xd.mid')
